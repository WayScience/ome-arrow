# %% [markdown]
# # OME-Arrow quiver

# %%
from ome_arrow import OMEArrow
OMEArrow(
    data="../../../tests/data/ome-artificial-5d-datasets/z-series.ome.tiff"
).view(how="pyvista")
# Out:
# Widget(value='<iframe src="http://localhost:61281/index.html?ui=P_0x17d5555d0_0&reconnect=auto" class="pyvista…

# %%
OMEArrow(
    data="../../../tests/data/nviz-artificial-4d-dataset/Z99_111_ZS005.tif"
)
# Out:
# 2D image - shape (T=1, C=1, Z=1, Y=128, X=128)

# %%
oa_image = OMEArrow(
    data="../../../tests/data/examplehuman/AS_09125_050116030001_D03f00d0.tif"
)
oa_image
# Out:
# 2D image - shape (T=1, C=1, Z=1, Y=512, X=512)

# %%
oa_image = OMEArrow(
    data="../../../tests/data/examplehuman/AS_09125_050116030001_D03f00d0.tif"
)
oa_image
# Out:
# 2D image - shape (T=1, C=1, Z=1, Y=512, X=512)

# %%
oa_image.info()
# Out:
# {'shape': (1, 1, 1, 512, 512),
#  'type': '2D image',
#  'summary': '2D image - shape (T=1, C=1, Z=1, Y=512, X=512)'}

# %%
oa_image.view(how="matplotlib")
# Out:
# <module 'matplotlib.pyplot' from '/Users/buntend/Documents/work/ome-arrow/.venv/lib/python3.11/site-packages/matplotlib/pyplot.py'>

# %%
OMEArrow(
    data="../../../tests/data/ome-artificial-5d-datasets/z-series.ome.tiff"
).view(how="pyvista")
# Out:
# Widget(value='<iframe src="http://localhost:61281/index.html?ui=P_0x17e660990_1&reconnect=auto" class="pyvista…

# %%
oa_image.export(how="numpy")
# Out:
# array([[[[[ 8,  8,  8, ..., 63, 78, 75],
#           [ 8,  8,  7, ..., 67, 71, 71],
#           [ 9,  8,  8, ..., 53, 64, 66],
#           ...,
#           [ 8,  9,  8, ..., 17, 24, 59],
#           [ 8,  8,  8, ..., 17, 22, 55],
#           [ 8,  8,  8, ..., 16, 18, 38]]]]],
#       shape=(1, 1, 1, 512, 512), dtype=uint16)
