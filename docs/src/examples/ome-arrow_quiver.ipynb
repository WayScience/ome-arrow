# %% [markdown]
# # OME-Arrow quiver

# %%
from ome_arrow import OMEArrow

# %%
oa_image = OMEArrow(
    data="../../../tests/data/examplehuman/AS_09125_050116030001_D03f00d0.tif"
)
oa_image
# Out:
# 2D image, single-channel - shape (T=1, C=1, Z=1, Y=512, X=512)

# %%
oa_image.info()
# Out:
# {'shape': (1, 1, 1, 512, 512),
#  'type': '2D image',
#  'channels': 1,
#  'is_multichannel': False,
#  'summary': '2D image, single-channel - shape (T=1, C=1, Z=1, Y=512, X=512)'}

# %%
oa_image.export(how="numpy")
# Out:
# array([[[[[ 8,  8,  8, ..., 63, 78, 75],
#           [ 8,  8,  7, ..., 67, 71, 71],
#           [ 9,  8,  8, ..., 53, 64, 66],
#           ...,
#           [ 8,  9,  8, ..., 17, 24, 59],
#           [ 8,  8,  8, ..., 17, 22, 55],
#           [ 8,  8,  8, ..., 16, 18, 38]]]]],
#       shape=(1, 1, 1, 512, 512), dtype=uint16)

# %%
stack = OMEArrow(
    data="../../../tests/data/nviz-artificial-4d-dataset/E99_C<111,222>_ZS<000-047>.tif",
    tcz=(0,0,20)
)
stack
# Out:
# 3D image (z-stack), multi-channel (2 channels) - shape (T=1, C=2, Z=48, Y=128, X=128)

# %%
stack_np = stack.export(how="numpy")
OMEArrow(data=stack_np, tcz=(0,0,20))
# Out:
# 3D image (z-stack), multi-channel (2 channels) - shape (T=1, C=2, Z=48, Y=128, X=128)

# %%
stack.export(how="ome-tiff", out="example.ome.tiff")
OMEArrow(data="example.ome.tiff", tcz=(0,0,20))
# Out:
# 3D image (z-stack), multi-channel (2 channels) - shape (T=1, C=2, Z=48, Y=128, X=128)

# %%
stack.export(how="ome-zarr", out="example.ome.zarr")
OMEArrow(data="example.ome.zarr", tcz=(0,0,20))
# Out:
# 3D image (z-stack), multi-channel (2 channels) - shape (T=1, C=2, Z=48, Y=128, X=128)

# %%
stack.export(how="ome-parquet", out="example.ome.parquet")
OMEArrow(data="example.ome.parquet", tcz=(0,0,20))
# Out:
# 3D image (z-stack), multi-channel (2 channels) - shape (T=1, C=2, Z=48, Y=128, X=128)

# %%
stack.view(how="pyvista")
# Out:
# Widget(value='<iframe src="http://localhost:60979/index.html?ui=P_0x35a158fd0_0&reconnect=auto" class="pyvista…
#                         <details>
#                         <summary>Static snapshot (for GitHub/nbviewer)</summary>
#                         <img src="data:image/png;base64,..." />
#                         </details>

# %%
stack.slice(x_min=40, y_min=80, x_max=70, y_max=110, t_indices=[0], c_indices=[0], z_indices=[20])
# Out:
# 2D image, single-channel - shape (T=1, C=1, Z=1, Y=30, X=30)
